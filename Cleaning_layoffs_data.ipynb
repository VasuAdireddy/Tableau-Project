# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"D:\Projects\Tableau\layoffs_data.csv")

# %%
data
# Out:
#             Company        Location        Industry  Laid_Off_Count  \
# 0            Swiggy       Bengaluru            Food           600.0
# 1           WeWork    New York City     Real Estate           300.0
# 2            Hubilo     SF Bay Area           Other           115.0
# 3        Riot Games     Los Angeles        Consumer            46.0
# 4            Fandom     SF Bay Area           Media             NaN
# ...             ...             ...             ...             ...
# 2017        Service     Los Angeles          Travel             NaN
# 2018   HopSkipDrive     Los Angeles  Transportation             8.0
# 2019    Panda Squad     SF Bay Area        Consumer             6.0
# 2020  Tamara Mellon     Los Angeles          Retail            20.0
# 2021       EasyPost  Salt Lake City       Logistics            75.0
#
#       Percentage                 Date  \
# 0           0.10  2023-01-19 00:00:00
# 1            NaN  2023-01-19 00:00:00
# ...

# %%
data=data.drop(['Date_Added', 'Stage','List_of_Employees_Laid_Off'],axis=1)
data
# Out:
#             Company        Location        Industry  Laid_Off_Count  \
# 0            Swiggy       Bengaluru            Food           600.0
# 1           WeWork    New York City     Real Estate           300.0
# 2            Hubilo     SF Bay Area           Other           115.0
# 3        Riot Games     Los Angeles        Consumer            46.0
# 4            Fandom     SF Bay Area           Media             NaN
# ...             ...             ...             ...             ...
# 2017        Service     Los Angeles          Travel             NaN
# 2018   HopSkipDrive     Los Angeles  Transportation             8.0
# 2019    Panda Squad     SF Bay Area        Consumer             6.0
# 2020  Tamara Mellon     Los Angeles          Retail            20.0
# 2021       EasyPost  Salt Lake City       Logistics            75.0
#
#       Percentage                 Date  \
# 0           0.10  2023-01-19 00:00:00
# 1            NaN  2023-01-19 00:00:00
# ...

# %%
data.isnull().sum()
# Out:
# Company             0
# Location            0
# Industry            0
# Laid_Off_Count    623
# Percentage        657
# Date                0
# Source              0
# Funds_Raised      153
# Country             0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Company           0
# Location          0
# Industry          0
# Laid_Off_Count    0
# Percentage        0
# Date              0
# Source            0
# Funds_Raised      0
# Country           0
# dtype: int64

# %%
data
# Out:
#              Company       Location        Industry  Laid_Off_Count  \
# 0             Swiggy      Bengaluru            Food           600.0
# 2             Hubilo    SF Bay Area           Other           115.0
# 10         Microsoft        Seattle           Other         10000.0
# 11            Sophos         Oxford        Security           450.0
# 12    Teladoc Health  New York City      Healthcare           300.0
# ...              ...            ...             ...             ...
# 2015       Inspirato         Denver          Travel           130.0
# 2016        Help.com         Austin         Support            16.0
# 2018    HopSkipDrive    Los Angeles  Transportation             8.0
# 2019     Panda Squad    SF Bay Area        Consumer             6.0
# 2020   Tamara Mellon    Los Angeles          Retail            20.0
#
#       Percentage                 Date  \
# 0           0.10  2023-01-19 00:00:00
# 2           0.35  2023-01-19 00:00:00
# ...

# %%
data.describe()
# Out:
#        Laid_Off_Count  Percentage   Funds_Raised
# count      971.000000  971.000000     971.000000
# mean       235.615860    0.231089     838.424156
# std        767.944724    0.212690    5885.830153
# min          3.000000    0.000000       0.000000
# 25%         36.000000    0.100000      58.000000
# 50%         78.000000    0.170000     163.000000
# 75%        170.000000    0.300000     453.000000
# max      11000.000000    1.000000  121900.000000

# %%
data =data.sort_values(by='Company')
data
# Out:
#            Company       Location    Industry  Laid_Off_Count  Percentage  \
# 356          &Open         Dublin   Marketing             9.0        0.09
# 815   10X Genomics    SF Bay Area  Healthcare           100.0        0.08
# 1860       1stdibs  New York City      Retail            70.0        0.17
# 1200           2TM      Sao Paulo      Crypto            90.0        0.12
# 690            2TM      Sao Paulo      Crypto           100.0        0.15
# ...            ...            ...         ...             ...         ...
# 397           iFit          Logan     Fitness           300.0        0.20
# 1162  iPrice Group   Kuala Lumpur      Retail            50.0        0.20
# 806         iRobot         Boston    Consumer           140.0        0.10
# 18           nCino     Wilmington     Finance           100.0        0.07
# 1905         uShip         Austin   Logistics            65.0        0.37
#
#                      Date                                             Source  \
# ...

# %%
data = data.drop_duplicates(subset='Company',keep='last')
data
# Out:
#            Company         Location    Industry  Laid_Off_Count  Percentage  \
# 356          &Open           Dublin   Marketing             9.0        0.09
# 815   10X Genomics      SF Bay Area  Healthcare           100.0        0.08
# 1860       1stdibs    New York City      Retail            70.0        0.17
# 690            2TM        Sao Paulo      Crypto           100.0        0.15
# 711         54gene  Washington D.C.  Healthcare            95.0        0.30
# ...            ...              ...         ...             ...         ...
# 397           iFit            Logan     Fitness           300.0        0.20
# 1162  iPrice Group     Kuala Lumpur      Retail            50.0        0.20
# 806         iRobot           Boston    Consumer           140.0        0.10
# 18           nCino       Wilmington     Finance           100.0        0.07
# 1905         uShip           Austin   Logistics            65.0        0.37
#
# ...

# %%
data.to_csv('layoffs_data_new.csv')
